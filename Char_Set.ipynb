# %%
import os

folder_path = "src-data/news2018/news2018/data/"
target_suffix = "_strn.v1.txt.trg"
data_dir = os.listdir(folder_path)
lang_set = {}

for lang_dir in data_dir:
    if lang_dir == ".DS_Store": # stupid MAC
        continue
    for f in os.listdir(os.path.join(folder_path, lang_dir)):
        if f.endswith(target_suffix):
            file_path = os.path.join(folder_path, lang_dir, f)
            file = open(file_path, 'r').read()
            uni_chars = set(file)
            print("Language =>", lang_dir)
            print("Unique Chars =>", len(uni_chars))
            lang_set[lang_dir] = uni_chars
# Out:
# Language => EnTa
# Unique Chars => 62
# Language => ThEn
# Unique Chars => 41
# Language => EnTh
# Unique Chars => 67
# Language => ChEn
# Unique Chars => 30
# Language => EnKa
# Unique Chars => 77
# Language => EnHi
# Unique Chars => 82
# Language => PeEn
# Unique Chars => 28
# Language => EnBa
# Unique Chars => 64
# Language => HeEn
# Unique Chars => 33
# Language => EnCh
# Unique Chars => 566
# Language => EnVi
# Unique Chars => 50
# Language => EnPe
# Unique Chars => 44
# Language => EnHe
# Unique Chars => 37

# %%
for lang in lang_set:
    print("lang:",lang, ", length:",len(lang_set[lang]))
    print(lang_set[lang])
# Out:
# lang: EnTa , length: 62
# {'க', '?', 'ு', 'ை', 'எ', '/', 'இ', 'ர', 'த', 'உ', 'ா', '_', 'ஸ', 'ஹ', '.', "'", ' ', 'I', 'ஊ', 'ோ', 'ஒ', 'ப', 'ஈ', '-', 'ூ', '\u200c', 'ங', 'ய', 'ீ', 'ன', 'வ', 'ௌ', 'ஜ', 'ி', 'ஷ', 'ே', 'V', ',', '0', 'ொ', '\n', 'ச', 'அ', 'ஃ', 'ற', 'ஏ', 'ல', 'ஞ', 'ட', 'ள', 'ஐ', 'ழ', 'ஓ', 'ெ', 'ஆ', 'ந', '1', 'ண', 'ஔ', 'ம', '2', '்'}
# lang: ThEn , length: 41
# {'h', '/', '(', 'n', 'e', 'w', 'd', 'b', 'l', '.', 'y', "'", ' ', 'a', '่', '-', 'k', '6', 'x', 'o', 't', '’', 'c', ',', 'z', 'f', 'i', 'q', '0', '\n', 'u', 'v', 'g', ')', 'j', 'r', '4', 's', 'p', '2', 'm'}
# lang: EnTh , length: 67
# {'้', 'ี', 'ญ', 'ฝ', '/', '๊', 'แ', 'ะ', '(', 'า', 'ข', 'ื', 'ม', 'ณ', '์', '.', 'ไ', 'อ', ' ', "'", 'ั', 'ง', 'ค', '่', 'เ', '-', 'ิ', 'ร', 'ฑ', 'ท', '๖', 'ล', 'ซ', 'ก', 'ว', 'ต', 'ศ', 'ฐ', 'ด', 'ผ', 'ช', 'ฉ', ',', '๐', 'บ', '\n', 'ย', 'ภ', ')', 'ถ', '๋', 'ฏ', 'ธ', 'ฆ', '็', 'ส', 'ู', 'พ', 'ึ', 'จ', 'ุ', 'โ', 'ห', 'น', 'ฟ', 'ป', 'ฮ'}
# lang: ChEn , length: 30
# {'h', 'n', 'e', 'd', 'w', 'b', 'l', 'y', "'", ' ', 'a', '-', 'k', 'x', 'o', 't', 'c', 'i', 'f', 'z', 'q', '\n', 'u', 'v', 'g', 'j', 'r', 's', 'p', 'm'}
# lang: EnKa , length: 77
# {'ಜ', 'ಝ', '?', 'ಊ', '/', '(', 'ೌ', 'ೂ', 'ಐ', 'ದ', 'ರ', 'ಛ', 'ಚ', 'ಇ', 'ಣ', 'ಹ', 'ಏ', 'ಋ', 'ಔ', 'ಮ', 'ಆ', 'ಲ', 'ೀ', 'ು', ' ', 'ಫ', 'ಿ', 'ಕ', 'ಈ', 'ಟ', '್', 'ಓ', 'I', 'ಥ', 'ಬ', 'ೃ', 'ಒ', '-', '\u200c', '6', 'ಾ', 'ಠ', '.', 'ಢ', 'ೊ', 'V', 'ೇ', 'ಯ', ',', '0', 'ಅ', 'ಡ', '\n', 'ಎ', 'ಷ', ')', 'X', 'ತ', 'ಞ', 'ೆ', 'ೋ', 'ಘ', 'ಖ', 'ಳ', 'ಸ', 'ಭ', 'ಪ', 'ಉ', 'ಧ', 'ಗ', 'ಶ', 'ೈ', 'ನ', '2', '1', 'ಂ', 'ವ'}
# lang: EnHi , length: 82
# {'ट', '?', 'ण', 'ऊ', 'ए', 'ृ', '(', 'ख', 'ॅ', 'फ़', '/', 'ऐ', 'उ', '़', 'म', 'ब', 'ओ', '्', 'भ', 'द', 'ल', 'औ', '.', 'थ', 'ञ', ' ', 'न', 'त', "'", 'ज', 'ड़', 'अ', 'क', 'फ', 'घ', 'ड', 'े', 'ू', 'ॉ', '-', 'ध', 'ह', 'स', '6', 'ष', 'व', 'ख़', 'ौ', 'र', 'ै', ',', '\u200d', 'ा', 'ढ़', 'ं', 'ज़', '\n', 'ो', 'ई', 'ऋ', 'ु', ')', ':', 'झ', '4', 'य', 'ढ', 'ग', 'ि', 'च', 'इ', 'ठ', 'ी', '1', 'ऑ', '2', 'ँ', 'क़', 'छ', 'आ', 'प', 'श'}
# lang: PeEn , length: 28
# {'h', 'n', 'e', 'd', 'w', 'b', 'l', 'y', ' ', 'a', 'k', 'x', 'o', 't', 'c', 'i', 'z', 'q', 'f', '\n', 'u', 'v', 'g', 'j', 'r', 's', 'p', 'm'}
# lang: EnBa , length: 64
# {'খ', 'ী', 'ে', 'ধ', 'ঃ', 'ই', 'এ', 'শ', 'চ', 'হ', 'ঈ', '২', 'ল', ' ', 'ৃ', 'ম', 'উ', 'ঢ', 'ঐ', 'য', 'ফ', 'া', 'দ', '়', 'ং', 'প', 'ঠ', '্', 'স', 'ছ', 'ঞ', 'ব', 'জ', 'ভ', 'ূ', 'ক', 'ঘ', 'র', 'অ', 'ড', 'ত', 'ড়', 'ঙ', 'ঊ', 'ঔ', 'ষ', '\n', 'ঋ', 'গ', 'ৈ', 'থ', 'ও', 'আ', 'ো', 'ঝ', '১', 'ট', 'য়', 'ি', 'ু', 'ৌ', 'ঁ', 'ণ', 'ন'}
# lang: HeEn , length: 33
# {'h', 'ů', 'n', 'e', 'd', 'w', 'b', 'l', '.', 'y', ' ', 'a', 'đ', 'k', 'x', 'o', 't', 'c', 'i', 'f', 'z', 'q', 'ľ', '\n', 'u', 'v', 'ß', 'g', 'j', 'r', 's', 'p', 'm'}
# lang: EnCh , length: 566
# {'舌', '博', '登', '娅', '白', '迪', '切', '特', '卜', '本', '邱', '惠', '戎', '沙', '兰', '革', '陶', '强', '薇', '印', '云', '尼', '可', '敏', '孙', '犹', '沃', '偌', '香', '盖', '龙', '查', '瑙', '欣', '聚', '菡', '老', '毕', '高', '凡', '通', '默', '方', '扎', '姆', '群', '洋', '圣', '秋', '红', '林', '华', '廷', '怀', '延', '透', '楼', '青', '典', '庇', '奥', '伍', '契', '梁', '匡', '冯', '库', '托', '邓', '寿', '几', '久', '易', '罕', '藏', '桢', '波', '内', '芝', '拜', '雷', '图', '希', '琳', '柯', '别', '莲', '汉', '嫩', '丝', '戈', '萝', '捷', '腊', '耀', '舍', '连', '次', '斯', '阔', '蒙', '柏', '伯', '吉', '牛', '富', '桑', '容', '津', '文', '莉', '冲', '尧', '曹', '鄂', '因', '道', '西', '明', '蓬', '来', '甫', '共', '渥', '农', '各', '比', '肯', '支', '黎', '哲', '苗', '郎', '千', '鸠', '威', '思', '祖', '果', '意', '裴', '美', '朱', '瑟', '答', '钱', '尚', '瓦', '保', '兹', '达', '浦', ' ', '极', '赛', '罗', '所', '雪', '咸', '鲁', '卢', '乔', '村', '坡', '莫', '纳', '苏', '雄', '得', '伊', '派', '烈', '洛', '侬', '泰', '戴', '场', '恩', '克', '年', '瑞', '棱', '科', '若', '贾', '斤', '多', '太', '士', '邦', '国', '辛', '都', '那', '角', '滕', '尤', '脱', '时', '嘉', '楚', '哥', '米', '\n', '范', '岑', '堪', '彭', '拿', '恰', '峡', '墨', '屈', '先', '主', '喀', '旧', '冰', '勒', '堡', '音', '土', '卓', '许', '九', '叶', '木', '肖', '庞', '阿', '茨', '港', '中', '霞', '安', '边', '普', '奇', '绍', '兆', '姜', '金', '狄', '拉', '钦', '铁', '新', '垂', '玛', '耶', '珍', '开', '诚', '诺', '张', '生', '昆', '斐', '城', '纪', '布', '霍', '梅', '孟', '坦', '治', '丘', '豪', '英', '班', '留', '基', '及', '厄', '万', '琴', '广', '昂', '佳', '密', '丽', '廖', '絮', '顺', '侯', '修', '丁', '大', '施', '佛', '伦', '古', '摩', '郡', '岸', '会', '蕾', '夫', '福', '樊', '平', '底', '齐', '塞', '朔', '外', '瓜', '略', '匹', '乌', '奴', '累', '合', '令', '逊', '绥', '也', '秘', '立', '珊', '穆', '伽', '歇', '夸', '爱', '敦', '儵', '马', '王', '莱', '柳', '纽', '封', '席', '洲', '茂', '卫', '崔', '甸', '史', '甲', '澳', '曼', '灵', '赖', '雅', '街', '湖', '扬', '顿', '人', '信', '兴', '俄', '热', '社', '荷', '彻', '讷', '廉', '萨', '宁', '刘', '娜', '皮', '迭', '赞', '提', '翁', '六', '毛', '龚', '何', '泼', '劳', '居', '帕', '芒', '非', '柴', '欧', '地', '塔', '法', '韦', '伐', '焦', '百', '李', '悉', '岛', '北', '映', '培', '芬', '唐', '耳', '采', '亨', '列', '露', '坚', '魏', '于', '哈', '山', '蒲', '卡', '根', '艾', '慕', '森', '葛', '色', '不', '措', '魁', '策', '汗', '奈', '贝', '越', '伏', '娃', '三', '宾', '詹', '康', '考', '当', '则', '格', '泽', '珀', '加', '丹', '玻', '朗', '温', '济', '凯', '屠', '南', '弗', '菲', '火', '真', '众', '尔', '松', '宗', '历', '和', '报', '杜', '锡', '倗', '芭', '梯', '昌', '曾', '贡', '蒂', '汇', '黛', '良', '礁', '梭', '俊', '门', '叙', '黑', '妮', '里', '晓', '联', '鲍', '子', '涅', '冈', '莎', '牙', '德', '约', '让', '宰', '佩', '汀', '吕', '的', '路', '夏', '代', '葆', '休', '永', '民', '然', '季', '甘', '陀', '娉', '海', '蔡', '缅', '杰', '巴', '坎', '聪', '旺', '丰', '包', '盛', '瀑', '第', '什', '启', '倍', '谷', '汤', '谢', '费', '赫', '亚', '佐', '江', '河', '滴', '忠', '东', '武', '琼', '宽', '舒', '圭', '察', '迈', '申', '日', '隆', '胡', '壁', '京', '努', '理', '洪', '茹', '儒', '彼', '薛', '维', '勃', '奎', '干', '孔', '麦', '利', '翰', '缪', '索', '潘', '撒', '义', '聂', '埃', '陆'}
# lang: EnVi , length: 50
# {'h', 'ầ', 'í', 'ê', 'n', 'e', 'ô', 'd', 'b', 'l', 'y', ' ', 'ố', 'a', 'ư', 'đ', 'k', 'ồ', 'ế', 'x', 'ý', 'o', 'ă', 't', 'á', 'ạ', 'ơ', 'é', 'ó', 'c', 'i', 'q', 'ấ', 'â', '\n', 'u', 'v', 'ọ', 'g', 'r', 'ú', 'ờ', 's', 'ậ', 'ắ', 'ợ', 'ẹ', 'p', 'ớ', 'm'}
# lang: EnPe , length: 44
# {'ﺵ', 'ﺽ', '»', 'ﺝ', 'ﺍ', 'ِ', 'ط', 'ﻥ', 'پ', 'ﺕ', 'ﻭ', 'ﻑ', ' ', 'ﺭ', 'ﺏ', 'گ', '\xad', 'ژ', '¥', 'ﺹ', 'ﺱ', 'ر', 'ﺩ', 'چ', 'ز', 'خ', 'ی', 'ﻝ', 'ک', 'ص', 'ﻡ', 'ﺥ', 'ذ', '\n', 'ُ', 'ﺡ', 'ﻕ', 'ﻉ', 'ﻍ', 'ﺯ', 'ﺙ', 'ﻩ', '﹀', 'ث'}
# lang: EnHe , length: 37
# {'ל', 'ד', 'w', 'פ', 'ג', '.', 'ع', "'", ' ', 'ש', 'ז', 'א', 'ט', 'מ', 'כ', 'ק', 'ا', 'ע', 'י', 'ס', 'ב', 'ת', 'و', 'ם', 'ץ', 'ص', 'ח', 'ו', 'נ', 'ר', 'ה', '\n', 'ך', 'צ', 'ן', 'ף', 'm'}

# %% [markdown]
# ### Fun Facts
#
# - For Persian, the first 32 letters are known and visible, the rest are not letters but can be used....
